# %%
import requests
import pandas as pd
import numpy as np
from textblob import TextBlob
from sklearn.model_selection import train_test_split

from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

api_key = 'AIzaSyBugiNIjhyaLI8gmZNnRPOo-y_qyP6weTk'
max = 100
video_id = 'nLEtkmVUMfU'
page_token = ''
url = 'https://www.googleapis.com/youtube/v3/commentThreads?key={api_key}&part=snippet&videoId={video_id}&maxResults={max}&pageToken={page_token}'
response = requests.get(url.format(api_key=api_key, video_id=video_id, max=max, page_token=page_token))

comments = []

for comment in response.json().get('items', []):
    comment_text = comment.get('snippet', {}).get('topLevelComment', {}).get('snippet', {}).get('textOriginal')

    if comment_text:
        comments.append(comment_text)

        print(comment_text)
# Out:
# Der Kanal "Marcosmologia" versucht die Menschheit erwachsen zu machen.
# Der Mensch ist ein Experiment der Natur, das zum scheitern verurteilt ist.
# Schlechte Doku
# Der Mensch ist eine Fehlentwicklung der Natur. Raffgierig, zerstörerisch ,ausrottend vor allem sich selbst.Total übeschätzend, es gibt ein tollen Spruch,,, DIE NATUR BRAUCHT UNS NICHT WIR  ABER BRAUCHEN SIE. Wenn er so weitermacht, ist sein überleben gleich ,, NULL,,, und das in kürzister Zeit .
# Demut und Liebe und absolute Bewunderung und Wertschätzung für unseren so grandiosen, wunderschönen Lebensraum dürfen wir endlich in Dankbarkeit für unser Geschenk Leben leben.
# In dieser Wandelzeit- dank dieser  so wenig geistig und körperlich gesunden Menschen- passt dieser Beitrag ganz besonders.
# Danke an ARTE für diesen tollen Beitrag.
# voll chillig
# Wenn der "Super"- Käfer das 20-fache seines Körpergewichts tragen kann, was der Mensch nicht kann, hat die Modellgesetze nicht verstanden.
# ...

# %%
with open('comments_DE.txt', 'w') as f:
    for comment in comment_text:
        for comment in comments:
            f.write(comment)

# %%
# !cat comments_DE.txt
# Out:
# Der Kanal "Marcosmologia" versucht die Menschheit erwachsen zu machen.Der Mensch ist ein Experiment der Natur, das zum scheitern verurteilt ist.Schlechte DokuDer Mensch ist eine Fehlentwicklung der Natur. Raffgierig, zerstörerisch ,ausrottend vor allem sich selbst.Total übeschätzend, es gibt ein tollen Spruch,,, DIE NATUR BRAUCHT UNS NICHT WIR  ABER BRAUCHEN SIE. Wenn er so weitermacht, ist sein überleben gleich ,, NULL,,, und das in kürzister Zeit .Demut und Liebe und absolute Bewunderung und Wertschätzung für unseren so grandiosen, wunderschönen Lebensraum dürfen wir endlich in Dankbarkeit für unser Geschenk Leben leben.
# In dieser Wandelzeit- dank dieser  so wenig geistig und körperlich gesunden Menschen- passt dieser Beitrag ganz besonders.
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
comm = pd.read_csv('nLEtkmVUMfU_csv_final.csv',encoding='utf8',error_bad_lines=False, index_col=0)
comm.head()
# Out:
#                                             Comments  \
# 0  Mann kann sich hier bei arte einfach keine Kom...
# 1  Da wird die Menschheit aber ziemlich schlecht ...
# 2  Man könnte denken aliens haben diese doku zur ...
# 3           Das ist doch Rassismus gegen Menschen 🤣🤣
# 4  Genauso sollte das unseren Kindern in der Schu...
#
#                    Comment ID  Reply Count  Like Count            Updated At  \
# 0  UgwF0k_LPwxgDyd2mTZ4AaABAg            0           0  2020-08-05T15:17:10Z
# 1  UgxQUQHM83Hw2PMW5Gl4AaABAg            1           0  2020-08-05T12:31:25Z
# 2  UgxSWsFbsl8oyxH1XS54AaABAg            1           0  2020-08-05T11:47:53Z
# 3  Ugw3ke-MtlziI1zPFjR4AaABAg            0           0  2020-08-05T11:47:30Z
# 4  UgxuhuYgvks80mBmY1N4AaABAg            0           0  2020-08-05T10:39:19Z
#
#   Viewer Rating
# 0          none
# 1          none
# 2          none
# 3          none
# 4          none

# %%
comm.info
# Out:
# <bound method DataFrame.info of                                                Comments  \
# 0     Mann kann sich hier bei arte einfach keine Kom...
# 1     Da wird die Menschheit aber ziemlich schlecht ...
# 2     Man könnte denken aliens haben diese doku zur ...
# 3              Das ist doch Rassismus gegen Menschen 🤣🤣
# 4     Genauso sollte das unseren Kindern in der Schu...
# ...                                                 ...
# 3212  Der Mensch muss sich über das ganze Universum ...
# 3213  Sehr interessant.\nVielen Dank für eure tollen...
# 3214  Der Mensch ist das schlimmste aller Tiere!\nVe...
# 3215                    Arte de ist kacke war nur spass
# 3216  Der Mensch ist Schöpfer Gottes\n-Ludwig Feuerbach
#
#                       Comment ID  Reply Count  Like Count  \
# 0     UgwF0k_LPwxgDyd2mTZ4AaABAg            0           0
# 1     UgxQUQHM83Hw2PMW5Gl4AaABAg            1           0
# 2     UgxSWsFbsl8oyxH1XS54AaABAg            1           0
# ...

# %%
comm.shape
# Out:
# (3217, 6)

# %% [markdown]
# ## Calculate Sentiment Polarity for each comment

# %%
pol=[] # list containing the polarity of the comments
for i in comm.Comments.values:
    try:
        analysis =TextBlob(i)
        pol.append(analysis.sentiment.polarity)
        
    except:
        pol.append(0)

# %% [markdown]
# #### Add new feature for polarity

# %%
comm['polarity']=comm['Comments'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
comm.head()
# Out:
#                                             Comments  \
# 0  Mann kann sich hier bei arte einfach keine Kom...
# 1  Da wird die Menschheit aber ziemlich schlecht ...
# 2  Man könnte denken aliens haben diese doku zur ...
# 3           Das ist doch Rassismus gegen Menschen 🤣🤣
# 4  Genauso sollte das unseren Kindern in der Schu...
#
#                    Comment ID  Reply Count  Like Count            Updated At  \
# 0  UgwF0k_LPwxgDyd2mTZ4AaABAg            0           0  2020-08-05T15:17:10Z
# 1  UgxQUQHM83Hw2PMW5Gl4AaABAg            1           0  2020-08-05T12:31:25Z
# 2  UgxSWsFbsl8oyxH1XS54AaABAg            1           0  2020-08-05T11:47:53Z
# 3  Ugw3ke-MtlziI1zPFjR4AaABAg            0           0  2020-08-05T11:47:30Z
# 4  UgxuhuYgvks80mBmY1N4AaABAg            0           0  2020-08-05T10:39:19Z
#
#   Viewer Rating  polarity
# 0          none       0.0
# 1          none       0.0
# 2          none      -0.1
# 3          none       0.0
# 4          none       0.0

# %%
comm.tail()
# Out:
#                                                Comments  \
# 3212  Der Mensch muss sich über das ganze Universum ...
# 3213  Sehr interessant.\nVielen Dank für eure tollen...
# 3214  Der Mensch ist das schlimmste aller Tiere!\nVe...
# 3215                    Arte de ist kacke war nur spass
# 3216  Der Mensch ist Schöpfer Gottes\n-Ludwig Feuerbach
#
#                       Comment ID  Reply Count  Like Count  \
# 3212  UgzZ7291xNPCAVQm8yt4AaABAg            2           6
# 3213  UgyodpnYUrj2ZrIEGAx4AaABAg            0           3
# 3214  Ugxi6bSuc3iz_1eIF854AaABAg            4          14
# 3215  Ugxo9KnZADKJu46a6CB4AaABAg            0           0
# 3216  UgwDIZyMaaCxVf21JSd4AaABAg           13          43
#
#                 Updated At Viewer Rating  polarity
# 3212  2019-05-19T13:06:55Z          none       0.0
# 3213  2019-05-19T13:06:19Z          none       0.0
# 3214  2019-05-19T13:11:45Z          none       0.0
# 3215  2019-05-19T13:04:51Z          none       0.0
# ...

# %%
comm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3217 entries, 0 to 3216
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Comments       3217 non-null   object
#  1   Comment ID     3217 non-null   object
#  2   Reply Count    3217 non-null   int64
#  3   Like Count     3217 non-null   int64
#  4   Updated At     3217 non-null   object
#  5   Viewer Rating  3217 non-null   object
#  6   polarity       3217 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 201.1+ KB

# %%
comm['pol_cat']=comm['pol_cat'][comm.polarity == 0] = 0
comm['pol_cat']=comm['pol_cat'][comm.polarity > 0] = 1
comm['pol_cat']=comm['pol_cat'][comm.polarity <= 0] = -1

# %%
comm.head()
# Out:
#                                             Comments  \
# 0  Mann kann sich hier bei arte einfach keine Kom...
# 1  Da wird die Menschheit aber ziemlich schlecht ...
# 2  Man könnte denken aliens haben diese doku zur ...
# 3           Das ist doch Rassismus gegen Menschen 🤣🤣
# 4  Genauso sollte das unseren Kindern in der Schu...
#
#                    Comment ID  Reply Count  Like Count            Updated At  \
# 0  UgwF0k_LPwxgDyd2mTZ4AaABAg            0           0  2020-08-05T15:17:10Z
# 1  UgxQUQHM83Hw2PMW5Gl4AaABAg            1           0  2020-08-05T12:31:25Z
# 2  UgxSWsFbsl8oyxH1XS54AaABAg            1           0  2020-08-05T11:47:53Z
# 3  Ugw3ke-MtlziI1zPFjR4AaABAg            0           0  2020-08-05T11:47:30Z
# 4  UgxuhuYgvks80mBmY1N4AaABAg            0           0  2020-08-05T10:39:19Z
#
#   Viewer Rating  polarity  pol_cat
# 0          none       0.0       -1
# 1          none       0.0       -1
# 2          none      -0.1       -1
# 3          none       0.0       -1
# ...

# %% [markdown]
# ### Lowercase comments
# Lowercasing comments to avoid being treated as two different words

# %%
comm['Comments'] = comm['Comments'].str.lower()

# %%
comm['Comments'].head()
# Out:
# 0    mann kann sich hier bei arte einfach keine kom...
# 1    da wird die menschheit aber ziemlich schlecht ...
# 2    man könnte denken aliens haben diese doku zur ...
# 3             das ist doch rassismus gegen menschen 🤣🤣
# 4    genauso sollte das unseren kindern in der schu...
# Name: Comments, dtype: object

# %% [markdown]
# ### Remove trailing spaces from comments

# %%
comm['Comments'] = comm['Comments'].str.strip()

# %% [markdown]
# ### Remove stop words

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stop_words = set(stopwords.words('german'))

def remove_stopwords(line):
    word_tokens = word_tokenize(line)
    filtered_sequence = [w for w in word_tokens if not w in stop_words]
    return " ".join(filtered_sequence)

# %%
comm['stop_comments'] = comm['Comments'].apply(lambda x : remove_stopwords(x))

# %%
comm.head(10)
# Out:
#                                             Comments  \
# 0  mann kann sich hier bei arte einfach keine kom...
# 1  da wird die menschheit aber ziemlich schlecht ...
# 2  man könnte denken aliens haben diese doku zur ...
# 3           das ist doch rassismus gegen menschen 🤣🤣
# 4  genauso sollte das unseren kindern in der schu...
# 5  die ganzen zahlenangaben sind reiner bulshit,v...
# 6          und? trotzdem beherrschen wir alle arten.
# 7  fehler! unsere sonnensystem befindet sich nich...
# 8                             scheiß arte-nwo penner
# 9                        der mensch oder die eliten?
#
#                    Comment ID  Reply Count  Like Count            Updated At  \
# 0  UgwF0k_LPwxgDyd2mTZ4AaABAg            0           0  2020-08-05T15:17:10Z
# 1  UgxQUQHM83Hw2PMW5Gl4AaABAg            1           0  2020-08-05T12:31:25Z
# 2  UgxSWsFbsl8oyxH1XS54AaABAg            1           0  2020-08-05T11:47:53Z
# ...

# %%
comm.drop_duplicates('Comment ID').shape
# Out:
# (3217, 9)

# %%
from collections import Counter, defaultdict
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import re
import regex
import emoji
import dateutil.parser
import spacy
import json


# r'S' matches anything until next whitespace
def remove_urls(text):
    return re.sub(r'https?://\S+', '', text)

# %%
stripped_urls = [remove_urls(comment) for comment in comm['stop_comments'].values]

# %%
unique_comments = Counter(stripped_urls)
print(unique_comments[''])
# Out:
# 0

# %%
comm['Stripped_urls'] = [remove_urls(comment) for comment in comm['stop_comments'].values]

# %%
comm['Lang'] = ''
comm.loc[comm['Stripped_urls'] == '', 'Lang'] = 'url'
comm.loc[comm['Stripped_urls'] != '', 'Lang'] = 'lang'

# %%
comm['Lang'].value_counts()
# Out:
# lang    3217
# Name: Lang, dtype: int64

# %%
comm['Lang'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# lang    100.0%
# Name: Lang, dtype: object

# %%
# Temporarily strip emojis for language detection
import demoji
demoji.download_codes()
# Out:
# ...
# ... OK (Got response in 0.33 seconds)
# Writing emoji data to /Users/kim-chido/.demoji/codes.json ...
# ... OK

# %%
demoji.replace("🥺hello there how are you", "")
# Out:
# 'hello there how are you'

# %%
comm['Stripped_emojis'] = [demoji.replace(comment) for comment in comm['Stripped_urls']]

# %%
pure_urls_and_emojis = len(comm[comm['Stripped_emojis'] == '' ])
pure_urls_and_emojis
# Out:
# 9

# %%
comm.loc[(comm['Lang'] == 'lang') & (comm['Stripped_emojis'] == ''), 'Lang'] = 'emoji'

# %%
pure_emojis = len(comm[comm['Lang'] == 'emoji'])
print(pure_urls_and_emojis - pure_emojis == len(comm[comm['Lang'] == 'url']))
# Out:
# True

# %%
comm['Lang'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# lang     99.7%
# emoji     0.3%
# Name: Lang, dtype: object

# %%
# Remove symbols and non-text characters

# %%
comm.head()
# Out:
#                                             Comments  \
# 0  mann kann sich hier bei arte einfach keine kom...
# 1  da wird die menschheit aber ziemlich schlecht ...
# 2  man könnte denken aliens haben diese doku zur ...
# 3           das ist doch rassismus gegen menschen 🤣🤣
# 4  genauso sollte das unseren kindern in der schu...
#
#                    Comment ID  Reply Count  Like Count            Updated At  \
# 0  UgwF0k_LPwxgDyd2mTZ4AaABAg            0           0  2020-08-05T15:17:10Z
# 1  UgxQUQHM83Hw2PMW5Gl4AaABAg            1           0  2020-08-05T12:31:25Z
# 2  UgxSWsFbsl8oyxH1XS54AaABAg            1           0  2020-08-05T11:47:53Z
# 3  Ugw3ke-MtlziI1zPFjR4AaABAg            0           0  2020-08-05T11:47:30Z
# 4  UgxuhuYgvks80mBmY1N4AaABAg            0           0  2020-08-05T10:39:19Z
#
#   Viewer Rating  polarity  pol_cat  \
# 0          none       0.0       -1
# 1          none       0.0       -1
# 2          none      -0.1       -1
# ...

# %%
comm.to_csv('YTDE_comments_2.csv') #, index=False)

# %%
stripped_df = comm['Stripped_emojis']
stripped_df.head()
# Out:
# 0    mann arte einfach kommentare mehr durchlesen v...
# 1    menschheit ziemlich schlecht gemacht . naja so...
# 2              denken aliens doku propaganda gemacht .
# 3                                  rassismus menschen
# 4    genauso kindern schule vermittelt . schöne dok...
# Name: Stripped_emojis, dtype: object

# %%
stripped_df.tail()
# Out:
# 3212                  mensch ganze universum ausbreiten .
# 3213               interessant . vielen dank tollen dokus
# 3214    mensch schlimmste tiere ! versklavung , umwelt...
# 3215                                  arte de kacke spass
# 3216             mensch schöpfer gottes -ludwig feuerbach
# Name: Stripped_emojis, dtype: object

# %%
comm.drop(columns=['Comments', 'Updated At', 'Viewer Rating', 'stop_comments', 'Stripped_urls'], inplace=True)

comm.to_csv('blurb.csv', index=False)

# %%
comm_1col=comm.drop(columns=['Comments', 'Viewer Rating', 'stop_comments', 'Stripped_urls'], inplace=True)

comm.to_csv('blurb.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-c24f299f36e7> in <module>
# ----> 1 comm_1col=comm.drop(columns=['Comments', 'Viewer Rating', 'stop_comments', 'Stripped_urls'], inplace=True)
#       2
#       3 comm.to_csv('blurb.csv', index=False)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
# ...

# %%
stop_df.tail()

# %%
stop_df.to_csv(r'comments.csv', header=None, index=None, sep=' ', mode='a')

# %% [markdown]
# ## Train Test Split
# Split the dataset into training and test data to start making predictions

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(comm['stop_comments'],comm['pol_cat'], test_size = 0.2, random_state = 4)

# %% [markdown]
# ## Extract Features from Text Data
# Use the CountVectorizer to create a vocabulary from the text data, storing the count of each word every time it appears in the text.

# %%
from sklearn.feature_extraction.text import CountVectorizer

vect= CountVectorizer()
tf_train = vect.fit_transform(X_train)
tf_test = vect.transform(X_test)

# %%
tf_train.shape

# %%
vect.vocabulary_

# %% [markdown]
# ## Sentiment Classification
# Use an LR Algorithm for classification.
# Logistic Regression will help in predicting the probability of outcomes i.e. binary classification or multi-classification. Examples of logistic regression include spam classifier, customer churn prediction, tumor prediction, etc.
#
#
#
# These are some of the famous examples of the same, while you can apply the same for other cases as in this instance of sentiment analysis, where there are two classes to classify i.e. either positive (1) or negative (-1).
#
#
#
# The scikit learn will be utilized to implement logistic regression for the sentiment classification.

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(tf_train, y_train)

# %%
lr.score(tf_train, y_train)

# %%
lr.score(tf_test, y_test)

# %% [markdown]
# #### Make predictions on the test dataset by using a model trained above:

# %%
expected = y_test
predicted = lr.predict(tf_test)

# %%
from sklearn.metrics import f1_score
f1_score(expected, predicted, average='macro')
